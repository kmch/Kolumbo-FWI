# %% [markdown]
# Here, gradient-smoothing is tuned on field-data inversion by investigating the trade-off between the model smoothness and data fit. For rationale, see the first paragraph of sect. `8.4` of the thesis. A generic inversion template is provided in `../template_inversion.ipynb`.

# %% [markdown]
# #### Notebook config

# %%
# %load ~/software/fullwavepy/fullwavepy/config/jupyter.py 
from fullwavepy import * # Load modules imported in fullwavepy/__init__.py
# -----------------------------------------------------------------------------
# Set aliases of frequently used jupyter magic commands
# -----------------------------------------------------------------------------
# %alias_magic mi matplotlib -p inline
# %alias_magic mn matplotlib -p notebook
# -----------------------------------------------------------------------------
# Set matplotlib backend
# -----------------------------------------------------------------------------
# non-interactive plots displayed in a notebook cell
# %matplotlib inline
# interactive plots displayed in a notebook cell
# %matplotlib notebook (interactive version)
# -----------------------------------------------------------------------------
# Set matplotlib style
# ----------------------------------------------------------------------------
plt.style.reload_library()
# a combined style (right overwrites left wherever they overlap):
plt.style.use(['default', 'ggplot'])
# print(plt.style.available) 
# -----------------------------------------------------------------------------
# Configure logging
# -----------------------------------------------------------------------------
# Set up loggers, handlers and load the log_lvl function
from fullwavepy.config.logging import *
# -----------------------------------------------------------------------------
# Set level of log-messages
log_lvl(ERROR) 
# Other options in order of increasing importance and 
# decreasing verbosity:
# TRACE, DEBUG, INFO, WARNING, ERROR, CRITICAL
# or using integers: 0, 10, 20, 30, 40, 50, respectively
# -----------------------------------------------------------------------------
# Autocompleting
# -----------------------------------------------------------------------------
#  Not sure if it works
#%config IPCompleter.greedy=True 
# -----------------------------------------------------------------------------
# Automatically reload modules before execution
#%load_ext autoreload
#%autoreload 2
# Out:
# Created `%mi` as an alias for `%matplotlib inline`.
# Created `%mn` as an alias for `%matplotlib notebook`.

# %%
xp = PROTEUS()
path_eph = '/home/kmc3817/rds_home/my_ephemeral/PROJECTS/ch08_Kolumbo_volcano'
exe = { 
    'fullwave':  '~/PhD/fullwave3D/rev690/bin/fullwave3D.exe',
    'fullwave_local': '/home/kmc3817/light_PhD/fullwave3D/rev690/bin/fullwave3D.exe',
    'segyprep':  '/home/kmc3817/light_PhD/fullwave3D/segyprep_v3.16/bin/segyprep_v3.16'} 
b01 = xp.box['kol1'].box

# %%
# !ls data
# Out:
# all_hy_traces_in_x8000_25000_y-3000_15000_box-OutSeis.sgy
# b01_subset
# bt_kol01_shape341x361.mmp
# bt_x8000_18000_y4000_14000_shape201x201.mmp
# dataset_obs_4104
# dataset_obs_hy_box01
# klaver2016_Kolumbo.csv
# kol_it160_vp.txt
# p14-Observed_HEAD.csv
# p14-Observed.sgy
# p14-StartVp_shape341x361x81.mmp
# recovered_models
# ueki_uwamori2016_Kolumbo.xlsx

# %% [markdown]
# ##### Init synthetic project (see `0831...ipynb`)

# %%
dis01 = {
 'dt': 0.0025,
 'dx': 50,
 'ns': 3000} # NOTE

# %%
info = "Calculate synthetics through p14.out.vp.it[80]"
s01 = ProjSyn('method_s01', path = './', exe=exe, info=info, box=b01, **dis01, cat=0)

# %% [markdown]
# # Init

# %%
from fullwavepy.fwi.project import ProjEnsemble
class SmoothEnsemble(ProjEnsemble):
    def __init__(self, *args, **kwargs):
        self.smooth = {}
        self.proj = {}
        super().__init__(*args, **kwargs)
    def init(self, smooth_values, *args, **kwargs):
        for smooth in smooth_values:
            pname = '%s_%s' % (self.name, smooth)
            self.proj[smooth] = ProjInv(pname, *args, **kwargs)

# %%
path = './'
dis02 = {'ns': 2500, 'dt': 0.0025, 'dx': 50}
en = SmoothEnsemble('field_smooth', path)
en.init([1,2,3], path=path, exe=exe, box=b01, **dis02, cat=0)

# %% [markdown]
# # Inp

# %% [markdown]
# ## Prep

# %% [markdown]
# ### Get raw data

# %%
# %%time 
for smooth, p in sorted(en.proj.items()):
    p.i.obs.raw.dupl(s01.i.ose.fname)
    p.i.rse.prep(fnames=[p.i.obs.raw.name])
# Out:
# Content of  .//field_smooth_1//inp/field_smooth_1-RawSeis.txt :
# field_smooth_1-Observed_raw.sgy
#
# Content of  .//field_smooth_2//inp/field_smooth_2-RawSeis.txt :
# field_smooth_2-Observed_raw.sgy
#
# Content of  .//field_smooth_3//inp/field_smooth_3-RawSeis.txt :
# field_smooth_3-Observed_raw.sgy
#
# CPU times: user 0 ns, sys: 32 ms, total: 32 ms
# Wall time: 4.15 s

# %%
figure(15)
p.i.obs.raw.plot(win=dict(tracf=[4104]), norm='max')

# %% [markdown]
# ### Source wavelet

# %%
for smooth, p in sorted(en.proj.items()):
    p.i.rsg.dupl('data/wavelet_19-09-22_ns2000_dt25ms.sgy')

# %%
p.i.rsg.plot()

# %% [markdown]
# ### Starting model

# %% [markdown]
# #### Vp

# %%
for smooth, p in sorted(en.proj.items()):
    p.i.svp.dupl('data/p14-StartVp_shape341x361x81.sgy')

# %%
p.i.svp.plot(coord=235)

# %% [markdown]
# #### Vs

# %% [markdown]
# #### Epsi

# %% [markdown]
# #### Delta

# %% [markdown]
# ### Preprocess input

# %%
# %%time 
for smooth, p in sorted(en.proj.items()):
    p.i.sp.prep(reciprocity=1, ztype='d')
    p.i.sp.run()
# Out:
# Content of  .//field_smooth_1//inp/field_smooth_1-SegyPrep.key :
# FFID : yes
# addtodepth : 0
# debug : yes
# dtms : 2.5
# dx : 50.0
# fixedarray : yes
# geometry : segy
# io : sgy
# maxoffset : 1000000.0
# minoffset : 0
# nx1 : 341
# nx2 : 361
# nx3 : 81
# outseis : yes
# outsource : yes
# problem : tomography
# reciprocity : 1
# retain : yes
# text : yes
# ttime : 6250.0
# unique : yes
# xorigin : 8000.0
# xshift : 0
# yorigin : -3000.0
# yshift : 0
# ztype : d
#
#
#  SEGYPREP  -  Version 3.16.04
#  ********
#
#  Data preparation for 2D & 3D wavefield tomography
#
#  Project name set to field_smooth_1
#  Preparing files for inversion...
#
#  Grid points in-line:                    341
#  Grid points cross-line:                 361
#  Grid points vertically:                  81
#  Horiz grid spacing (metres):      50.0000000
#  Vert grid spacing (metres):       50.0000000
#  Model length (metres):            17000.0000
#  Model width (metres):             18000.0000
#  Model depth (metres):             4000.00000
#
#  Modelling time step (ms):         2.50000000
#  Output data delta-T (ms):         2.50000000
#  Output data length (ms):          6250.00000
#  Output data length (samples):          2500
#  Time steps to model:                   2500
#
#  Receiver-array fixed in space:          yes
#  Renumber original channel numbers:       no
#  Use FFID instead of SOURCE numbers:     yes
#  FFID numbers are unique:                yes
#  Renumber original FFID numbers:          no
#  Use composite shots:                     no
#  Apply source-receiver reciprocity:      yes
#
#  Reading multiple SEG-Y datafiles...
#  Reading: field_smooth_1-Observed_raw.sgy
#  No of traces in SEG-Y datafile:       24080
#  Traces read from file:                24080
#
#  Total traces used:                    24080
#  Reciprocal sources in model:             16
#  Reciprocal receivers in model:         1505
#  Maximum receivers per source:          1505
#
#  Reading source signatures...
#
#  Checking models...
#
#  Cannot open SGY file
#  Cannot open SGY file
#  Found model file field_smooth_1-StartVp.sgy
#  Vertical grid points in file:            81
#  Expecting:                               81
#  Profiles in file:                    123101
#  Expecting:                           123101
#  Maximum velocity (m/s):              6515.1
#  Minimum velocity (m/s):              1517.4
#  For high kernel:
#  Maximum allowable (m/s):            13187.0
#  High kernel OK below (Hz):              9.0
#  For low kernel:
#  Maximum allowable (m/s):             9900.0
#  Low kernel OK below (Hz):               4.9
#
#  Plotting retained sources...
#  Plotting retained receivers...
#  Plots complete
#
#
# Content of  .//field_smooth_2//inp/field_smooth_2-SegyPrep.key :
# FFID : yes
# addtodepth : 0
# debug : yes
# dtms : 2.5
# dx : 50.0
# fixedarray : yes
# geometry : segy
# io : sgy
# maxoffset : 1000000.0
# minoffset : 0
# nx1 : 341
# nx2 : 361
# nx3 : 81
# outseis : yes
# outsource : yes
# problem : tomography
# reciprocity : 1
# retain : yes
# text : yes
# ttime : 6250.0
# unique : yes
# xorigin : 8000.0
# xshift : 0
# yorigin : -3000.0
# yshift : 0
# ztype : d
#
#
#  SEGYPREP  -  Version 3.16.04
#  ********
#
#  Data preparation for 2D & 3D wavefield tomography
#
#  Project name set to field_smooth_2
#  Preparing files for inversion...
#
#  Grid points in-line:                    341
#  Grid points cross-line:                 361
#  Grid points vertically:                  81
#  Horiz grid spacing (metres):      50.0000000
#  Vert grid spacing (metres):       50.0000000
#  Model length (metres):            17000.0000
#  Model width (metres):             18000.0000
#  Model depth (metres):             4000.00000
#
#  Modelling time step (ms):         2.50000000
#  Output data delta-T (ms):         2.50000000
#  Output data length (ms):          6250.00000
#  Output data length (samples):          2500
#  Time steps to model:                   2500
#
#  Receiver-array fixed in space:          yes
#  Renumber original channel numbers:       no
#  Use FFID instead of SOURCE numbers:     yes
#  FFID numbers are unique:                yes
#  Renumber original FFID numbers:          no
#  Use composite shots:                     no
#  Apply source-receiver reciprocity:      yes
#
#  Reading multiple SEG-Y datafiles...
#  Reading: field_smooth_2-Observed_raw.sgy
#  No of traces in SEG-Y datafile:       24080
#  Traces read from file:                24080
#
#  Total traces used:                    24080
#  Reciprocal sources in model:             16
#  Reciprocal receivers in model:         1505
#  Maximum receivers per source:          1505
#
#  Reading source signatures...
#
#  Checking models...
#
#  Cannot open SGY file
#  Cannot open SGY file
#  Found model file field_smooth_2-StartVp.sgy
#  Vertical grid points in file:            81
#  Expecting:                               81
#  Profiles in file:                    123101
#  Expecting:                           123101
#  Maximum velocity (m/s):              6515.1
#  Minimum velocity (m/s):              1517.4
#  For high kernel:
#  Maximum allowable (m/s):            13187.0
#  High kernel OK below (Hz):              9.0
#  For low kernel:
#  Maximum allowable (m/s):             9900.0
#  Low kernel OK below (Hz):               4.9
#
#  Plotting retained sources...
#  Plotting retained receivers...
#  Plots complete
#
#
# Content of  .//field_smooth_3//inp/field_smooth_3-SegyPrep.key :
# FFID : yes
# addtodepth : 0
# debug : yes
# dtms : 2.5
# dx : 50.0
# fixedarray : yes
# geometry : segy
# io : sgy
# maxoffset : 1000000.0
# minoffset : 0
# nx1 : 341
# nx2 : 361
# nx3 : 81
# outseis : yes
# outsource : yes
# problem : tomography
# reciprocity : 1
# retain : yes
# text : yes
# ttime : 6250.0
# unique : yes
# xorigin : 8000.0
# xshift : 0
# yorigin : -3000.0
# yshift : 0
# ztype : d
#
#
#  SEGYPREP  -  Version 3.16.04
#  ********
#
#  Data preparation for 2D & 3D wavefield tomography
#
#  Project name set to field_smooth_3
#  Preparing files for inversion...
#
#  Grid points in-line:                    341
#  Grid points cross-line:                 361
#  Grid points vertically:                  81
#  Horiz grid spacing (metres):      50.0000000
#  Vert grid spacing (metres):       50.0000000
#  Model length (metres):            17000.0000
#  Model width (metres):             18000.0000
#  Model depth (metres):             4000.00000
#
#  Modelling time step (ms):         2.50000000
#  Output data delta-T (ms):         2.50000000
#  Output data length (ms):          6250.00000
#  Output data length (samples):          2500
#  Time steps to model:                   2500
#
#  Receiver-array fixed in space:          yes
#  Renumber original channel numbers:       no
#  Use FFID instead of SOURCE numbers:     yes
#  FFID numbers are unique:                yes
#  Renumber original FFID numbers:          no
#  Use composite shots:                     no
#  Apply source-receiver reciprocity:      yes
#
#  Reading multiple SEG-Y datafiles...
#  Reading: field_smooth_3-Observed_raw.sgy
#  No of traces in SEG-Y datafile:       24080
#  Traces read from file:                24080
#
#  Total traces used:                    24080
#  Reciprocal sources in model:             16
#  Reciprocal receivers in model:         1505
#  Maximum receivers per source:          1505
#
#  Reading source signatures...
#
#  Checking models...
#
#  Cannot open SGY file
#  Cannot open SGY file
#  Found model file field_smooth_3-StartVp.sgy
#  Vertical grid points in file:            81
#  Expecting:                               81
#  Profiles in file:                    123101
#  Expecting:                           123101
#  Maximum velocity (m/s):              6515.1
#  Minimum velocity (m/s):              1517.4
#  For high kernel:
#  Maximum allowable (m/s):            13187.0
#  High kernel OK below (Hz):              9.0
#  For low kernel:
#  Maximum allowable (m/s):             9900.0
#  Low kernel OK below (Hz):               4.9
#
#  Plotting retained sources...
#  Plotting retained receivers...
#  Plots complete
#
#
# CPU times: user 20 ms, sys: 24 ms, total: 44 ms
# Wall time: 31.1 s

# %% [markdown]
# ### Process data

# %%
# %%time 
kw_filt = {'pad': 100, 'f1': 2, 'f2': 3, 'f3': 4.5, 'f4': 6.5, 'zerophase': False}
kw_mute = {'twin': 1, 'syn_file': s01.o.syn}
for smooth, p in sorted(en.proj.items()):
    p.i.obs.process(kw_filt, kw_mute)
# Out:
# CPU times: user 5min 31s, sys: 4.2 s, total: 5min 35s
# Wall time: 7min 18s

# %%
figure(15)
p.i.obs.plot(win=dict(tracf=[4104]), norm='max')
plt.xlim(0,400)
# Out:
# (0, 400)

# %% [markdown]
# ### Runfile

# %%
# %%time 
for smooth, p in sorted(en.proj.items()):
    p.i.rnf.prep(sx1=smooth, sx2=smooth, sx3=smooth, # that's the whole point!!!!!
                 b_abs=40, e_abs=50)
# Out:
# Content of  .//field_smooth_1//inp/field_smooth_1-Runfile.key :
#
#     ! May 2019, K. Chrapkiewicz
#     ! THIS RUNFILE CONFORMS TO
#     ! FULLWAVE REV. 688 STANDARD
#
#
#     ! A. PROBLEM DEFINITION
#      problem       : tomography
#      domain        : time
#      dim           : 3d
#      equation      : acoustic
#      units         : metric
#      anisotropy    : none
#      kernel        : low
#
#
#     ! B. MODEL DEFINITION
#      nx1           : 341
#      nx2           : 361
#      nx3           : 81
#      dx            : 50.0000000
#
#
#     ! C. DATA DEFINITION
#      ncomp         : 16
#      nshots        : 16
#      nrecs         : 1505
#      maxrc         : 1505
#      maxps         : 1
#      io            : segy
#
#
#     ! D. BOUNDARY CONDITIONS
#      ibfs          : 0
#      multisurf     : 0
#      nosprdfctrs   : 0
#      seaLevel      : 0
#      maxGhostIter  : 2
#      vacuum        : 0
#      accuracy      : 0.001
#      minGhostFS    : 0.001
#      minFictFS     : 0.5
#      interpMode    : 1
#
#      btop          : 0
#      bbot          : 40
#      bleft         : 40
#      bright        : 40
#      bfront        : 40
#      bback         : 40
#
#      etop          : 0
#      ebot          : 50
#      elef          : 50
#      erig          : 50
#      efro          : 50
#      ebac          : 50
#
#
#     ! F. MUTES & DATA SELECTION
#      etime         : 6.25
#
#
#     ! G. INVERSION PARAMETERS
#      iprop         : vp       ! INVERT PROPERTIES
#      func          : twonorm  ! FUNCTIONAL
#      agc           : off      ! DEFAULT: off
#      amplitude     : no       ! DEFAULT: no
#      normalise     : yes      ! DEFAULT: yes
#      spatial       : yes      ! SPATIAL PRECONDITIONER; DEFAULT: yes
#      slowness      : yes      ! DEFAULT: yes
#      conj          : no       ! CONJUGATE GRADIENT; DEFAULT: no
#      gwidth        : 0.0      ! GAUSSIAN WIDTH; DEFAULT: 0.0
#
#      !OMITTED: huber
#
#
#     ! H. SMOOTHING & WINDOWING
#      usewin        : no
#      win1          : 1
#      win2          : 1
#      win3          : 10000
#      win4          : 10000
#
#      sx1           : 1
#      sx2           : 1
#      sx3           : 1
#
#      !OMITTED: smooth,
#      !         asx1, asx2, asx3, fins, finsx1, finsx2, finsx3,
#      !         finscut, finsramp
#
#
#     ! I. P-WAVE VELOCITY MODEL
#      velcut        : 1550     ! [m/s] DO NOT UPDATE FOR ALL x : ANY_PARAM(x) < velcut
#
#      !OMITTED: minvc, maxvc
#
#
#     ! J. DENSITY MODEL
#      wvel          : 1550     ! [m/s]   WATER VEL. (SETS wden FOR ALL x : Vp(x) <= wvel)
#      wden          : 1000     ! [kg/m3] WATER DEN.
#      gvel          : 1600     ! [m/s]   GARDNER CUTOFF VEL.
#
#      !OMITTED: max water cell (gcell), min water cell
#
#
#     ! K. ANISOTROPY MODEL
#      !OMITTED: minec, maxec, mindc, maxdc, ttiu, angle
#
#
#     ! L. ELASTIC MODEL
#      !OMITTED: minvsc, maxvsc, vp to vs, vpzero,
#
#
#     ! M. EPICMods
#      !OMITTED: ALL
#
#
#     ! N. GLOBAL INVERSION VIA qPSO
#      !OMITTED: ALL
#
#
#     ! E. ITERATIONS & DATA SELECTION (THE LAST PART OF THE FILE)
#      nblock        : 8
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 3.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 3.5
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 4.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 4.5
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 5.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 5.5
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 6.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 6.5
#
#
# Content of  .//field_smooth_2//inp/field_smooth_2-Runfile.key :
#
#     ! May 2019, K. Chrapkiewicz
#     ! THIS RUNFILE CONFORMS TO
#     ! FULLWAVE REV. 688 STANDARD
#
#
#     ! A. PROBLEM DEFINITION
#      problem       : tomography
#      domain        : time
#      dim           : 3d
#      equation      : acoustic
#      units         : metric
#      anisotropy    : none
#      kernel        : low
#
#
#     ! B. MODEL DEFINITION
#      nx1           : 341
#      nx2           : 361
#      nx3           : 81
#      dx            : 50.0000000
#
#
#     ! C. DATA DEFINITION
#      ncomp         : 16
#      nshots        : 16
#      nrecs         : 1505
#      maxrc         : 1505
#      maxps         : 1
#      io            : segy
#
#
#     ! D. BOUNDARY CONDITIONS
#      ibfs          : 0
#      multisurf     : 0
#      nosprdfctrs   : 0
#      seaLevel      : 0
#      maxGhostIter  : 2
#      vacuum        : 0
#      accuracy      : 0.001
#      minGhostFS    : 0.001
#      minFictFS     : 0.5
#      interpMode    : 1
#
#      btop          : 0
#      bbot          : 40
#      bleft         : 40
#      bright        : 40
#      bfront        : 40
#      bback         : 40
#
#      etop          : 0
#      ebot          : 50
#      elef          : 50
#      erig          : 50
#      efro          : 50
#      ebac          : 50
#
#
#     ! F. MUTES & DATA SELECTION
#      etime         : 6.25
#
#
#     ! G. INVERSION PARAMETERS
#      iprop         : vp       ! INVERT PROPERTIES
#      func          : twonorm  ! FUNCTIONAL
#      agc           : off      ! DEFAULT: off
#      amplitude     : no       ! DEFAULT: no
#      normalise     : yes      ! DEFAULT: yes
#      spatial       : yes      ! SPATIAL PRECONDITIONER; DEFAULT: yes
#      slowness      : yes      ! DEFAULT: yes
#      conj          : no       ! CONJUGATE GRADIENT; DEFAULT: no
#      gwidth        : 0.0      ! GAUSSIAN WIDTH; DEFAULT: 0.0
#
#      !OMITTED: huber
#
#
#     ! H. SMOOTHING & WINDOWING
#      usewin        : no
#      win1          : 1
#      win2          : 1
#      win3          : 10000
#      win4          : 10000
#
#      sx1           : 2
#      sx2           : 2
#      sx3           : 2
#
#      !OMITTED: smooth,
#      !         asx1, asx2, asx3, fins, finsx1, finsx2, finsx3,
#      !         finscut, finsramp
#
#
#     ! I. P-WAVE VELOCITY MODEL
#      velcut        : 1550     ! [m/s] DO NOT UPDATE FOR ALL x : ANY_PARAM(x) < velcut
#
#      !OMITTED: minvc, maxvc
#
#
#     ! J. DENSITY MODEL
#      wvel          : 1550     ! [m/s]   WATER VEL. (SETS wden FOR ALL x : Vp(x) <= wvel)
#      wden          : 1000     ! [kg/m3] WATER DEN.
#      gvel          : 1600     ! [m/s]   GARDNER CUTOFF VEL.
#
#      !OMITTED: max water cell (gcell), min water cell
#
#
#     ! K. ANISOTROPY MODEL
#      !OMITTED: minec, maxec, mindc, maxdc, ttiu, angle
#
#
#     ! L. ELASTIC MODEL
#      !OMITTED: minvsc, maxvsc, vp to vs, vpzero,
#
#
#     ! M. EPICMods
#      !OMITTED: ALL
#
#
#     ! N. GLOBAL INVERSION VIA qPSO
#      !OMITTED: ALL
#
#
#     ! E. ITERATIONS & DATA SELECTION (THE LAST PART OF THE FILE)
#      nblock        : 8
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 3.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 3.5
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 4.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 4.5
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 5.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 5.5
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 6.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 6.5
#
#
# Content of  .//field_smooth_3//inp/field_smooth_3-Runfile.key :
#
#     ! May 2019, K. Chrapkiewicz
#     ! THIS RUNFILE CONFORMS TO
#     ! FULLWAVE REV. 688 STANDARD
#
#
#     ! A. PROBLEM DEFINITION
#      problem       : tomography
#      domain        : time
#      dim           : 3d
#      equation      : acoustic
#      units         : metric
#      anisotropy    : none
#      kernel        : low
#
#
#     ! B. MODEL DEFINITION
#      nx1           : 341
#      nx2           : 361
#      nx3           : 81
#      dx            : 50.0000000
#
#
#     ! C. DATA DEFINITION
#      ncomp         : 16
#      nshots        : 16
#      nrecs         : 1505
#      maxrc         : 1505
#      maxps         : 1
#      io            : segy
#
#
#     ! D. BOUNDARY CONDITIONS
#      ibfs          : 0
#      multisurf     : 0
#      nosprdfctrs   : 0
#      seaLevel      : 0
#      maxGhostIter  : 2
#      vacuum        : 0
#      accuracy      : 0.001
#      minGhostFS    : 0.001
#      minFictFS     : 0.5
#      interpMode    : 1
#
#      btop          : 0
#      bbot          : 40
#      bleft         : 40
#      bright        : 40
#      bfront        : 40
#      bback         : 40
#
#      etop          : 0
#      ebot          : 50
#      elef          : 50
#      erig          : 50
#      efro          : 50
#      ebac          : 50
#
#
#     ! F. MUTES & DATA SELECTION
#      etime         : 6.25
#
#
#     ! G. INVERSION PARAMETERS
#      iprop         : vp       ! INVERT PROPERTIES
#      func          : twonorm  ! FUNCTIONAL
#      agc           : off      ! DEFAULT: off
#      amplitude     : no       ! DEFAULT: no
#      normalise     : yes      ! DEFAULT: yes
#      spatial       : yes      ! SPATIAL PRECONDITIONER; DEFAULT: yes
#      slowness      : yes      ! DEFAULT: yes
#      conj          : no       ! CONJUGATE GRADIENT; DEFAULT: no
#      gwidth        : 0.0      ! GAUSSIAN WIDTH; DEFAULT: 0.0
#
#      !OMITTED: huber
#
#
#     ! H. SMOOTHING & WINDOWING
#      usewin        : no
#      win1          : 1
#      win2          : 1
#      win3          : 10000
#      win4          : 10000
#
#      sx1           : 3
#      sx2           : 3
#      sx3           : 3
#
#      !OMITTED: smooth,
#      !         asx1, asx2, asx3, fins, finsx1, finsx2, finsx3,
#      !         finscut, finsramp
#
#
#     ! I. P-WAVE VELOCITY MODEL
#      velcut        : 1550     ! [m/s] DO NOT UPDATE FOR ALL x : ANY_PARAM(x) < velcut
#
#      !OMITTED: minvc, maxvc
#
#
#     ! J. DENSITY MODEL
#      wvel          : 1550     ! [m/s]   WATER VEL. (SETS wden FOR ALL x : Vp(x) <= wvel)
#      wden          : 1000     ! [kg/m3] WATER DEN.
#      gvel          : 1600     ! [m/s]   GARDNER CUTOFF VEL.
#
#      !OMITTED: max water cell (gcell), min water cell
#
#
#     ! K. ANISOTROPY MODEL
#      !OMITTED: minec, maxec, mindc, maxdc, ttiu, angle
#
#
#     ! L. ELASTIC MODEL
#      !OMITTED: minvsc, maxvsc, vp to vs, vpzero,
#
#
#     ! M. EPICMods
#      !OMITTED: ALL
#
#
#     ! N. GLOBAL INVERSION VIA qPSO
#      !OMITTED: ALL
#
#
#     ! E. ITERATIONS & DATA SELECTION (THE LAST PART OF THE FILE)
#      nblock        : 8
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 3.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 3.5
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 4.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 4.5
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 5.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 5.5
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 6.0
#
#      nits          : 20
#      minoff        : 5000
#      freq          : 6.5
#
#
# CPU times: user 20 ms, sys: 36 ms, total: 56 ms
# Wall time: 142 ms

# %% [markdown]
# ## Check

# %%
# %%time 
lll(20)
for smooth, p in sorted(en.proj.items()):
    p.i.check_by_fullwave()
    p.i.obs.surange() # above doesn't check if data exist
lll(40)
# Out:
# INFO:fullwavepy.project.generic.io.ProjInput.check_by_fullwave:
#
# Fullwave is checking the input...
# (exe = /home/kmc3817/light_PhD/fullwave3D/rev690/bin/fullwave3D.exe)
# INFO:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: Checked input & dumped canonical runfile
# WARNING:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: Note, accuracy criterion is not checked by Fullwave.
# WARNING:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: Make sure log_lvl<=20 in order to see the full log.
# INFO:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: +++++++++++++++ Will only check input files and dump canonical runfile ++++++++++++++++
# ---=== Starting run (host: ese-kajetan) on 2021/11/12, 21:21:38 ===---
# executable: fullwave3D.exe, version: unknown, release date: 2021-08-31
# === scheduler_getprojargs: Project name (command-line argument): "field_smooth_1"
# === setup_probtype: Equation: "acoustic", Anisotropy: "none", Domain: "time", Kernel: "low"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "ibfs"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "multisurf"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "nosprdfctrs"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "seaLevel"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "maxGhostIter"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "vacuum"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "accuracy"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "minGhostFS"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "minFictFS"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "interpMode"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "iprop"
#     read_runfile: number of iteration blocks in "field_smooth_1-Runfile.key": 8
#     read_runfile: total time given in "field_smooth_1-Runfile.key": 6.25000000 seconds
#     scheduler_readinput: Grid dimensions (Length x Width x Depth): 441x461x133 cells
#     read_modelprop: Got Vp model from "field_smooth_1-StartVp.sgy"
#     scheduler_readinput: Initial min/max Vp (m/s): 1517.41, 6515.07
#     scheduler_readinput: Initial min/max Qp: 0.00, 0.00
#     scheduler_readinput: Max. reliable pressure wave propagation frequency on this grid is about 6.07Hz
#     scheduler_run: Starting new iteration block (1) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     getall: Time-step: 2.5000E-03, maximum trace-length: 6.2500E+00
#     getall: number of composite shots found in "field_smooth_1-Signature.sgy": 16
#     GetShotPointReceiverTracesInfo: number of composite shots found in "field_smooth_1-Observed.sgy": 16
#     scheduler_run: Starting new iteration block (2) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (3) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (4) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (5) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (6) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (7) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (8) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#   - scheduler_outputrunfile: dumping canonical runfile to field_smooth_1-Canonical-Runfile.key
# ---=== Checked input & dumped canonical runfile - finished on 2021/11/12, 21:21:40 ===---
#
# 3200+0 records in
# 6+1 records out
# 3200 bytes (3.2 kB, 3.1 KiB) copied, 0.00325759 s, 982 kB/s
#
# 24080 traces:
# tracl    3555 13370 (3555 - 13370)
# tracr    1 24080 (1 - 24080)
# fldr     17567 42821 (17567 - 42821)
# tracf    4104 4178 (4104 - 4176)
# ep       5 38 (5 - 38)
# cdpt     0 1 (0 - 1)
# trid     1
# offset   10 21208 (10473 - 19597)
# gelev    196 456 (417 - 410)
# selev    -12
# sdepth   12
# swdep    45 503 (395 - 393)
# gwdep    196 456 (417 - 410)
# scalel   1
# scalco   1
# sx       8051 24996 (8201 - 8128)
# sy       -2126 13847 (13742 - 13727)
# gx       8863 24030 (18674 - 21101)
# gy       -1040 13806 (13806 - -960)
# counit   1
# tstat    250
# delrt    0 5 (0 - 4)
# muts     338 6023 (3435 - 4990)
# mute     1338 7023 (4435 - 5990)
# ns       2500
# dt       2500
# gain     0 1 (1 - 0)
# igc      0 16 (16 - 0)
# year     2015
# day      331 340 (331 - 340)
# hour     0 23 (3 - 15)
# minute   0 59 (4 - 18)
# sec      0 59 (55 - 43)
# timbas   0 1000 (435 - 737)
# ntr      24080
# shortpad -20349 31289 (-20349 - 21520)
#
# Shot coordinate limits:
# 	North(23852,13847) South(10038,-2126) East(24996,656) West(8051,11996)
#
# Receiver coordinate limits:
# 	North(18674,13806) South(9821,-1040) East(24030,7042) West(8863,4208)
#
# Midpoint coordinate limits:
# 	North(21263,13826.5) South(9929.5,-1583) East(24513,3849) West(8457,8102)
#
# INFO:fullwavepy.project.generic.io.ProjInput.check_by_fullwave:
#
# Fullwave is checking the input...
# (exe = /home/kmc3817/light_PhD/fullwave3D/rev690/bin/fullwave3D.exe)
# INFO:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: Checked input & dumped canonical runfile
# WARNING:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: Note, accuracy criterion is not checked by Fullwave.
# WARNING:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: Make sure log_lvl<=20 in order to see the full log.
# INFO:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: +++++++++++++++ Will only check input files and dump canonical runfile ++++++++++++++++
# ---=== Starting run (host: ese-kajetan) on 2021/11/12, 21:21:41 ===---
# executable: fullwave3D.exe, version: unknown, release date: 2021-08-31
# === scheduler_getprojargs: Project name (command-line argument): "field_smooth_2"
# === setup_probtype: Equation: "acoustic", Anisotropy: "none", Domain: "time", Kernel: "low"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "ibfs"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "multisurf"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "nosprdfctrs"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "seaLevel"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "maxGhostIter"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "vacuum"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "accuracy"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "minGhostFS"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "minFictFS"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "interpMode"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "iprop"
#     read_runfile: number of iteration blocks in "field_smooth_2-Runfile.key": 8
#     read_runfile: total time given in "field_smooth_2-Runfile.key": 6.25000000 seconds
#     scheduler_readinput: Grid dimensions (Length x Width x Depth): 441x461x133 cells
#     read_modelprop: Got Vp model from "field_smooth_2-StartVp.sgy"
#     scheduler_readinput: Initial min/max Vp (m/s): 1517.41, 6515.07
#     scheduler_readinput: Initial min/max Qp: 0.00, 0.00
#     scheduler_readinput: Max. reliable pressure wave propagation frequency on this grid is about 6.07Hz
#     scheduler_run: Starting new iteration block (1) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     getall: Time-step: 2.5000E-03, maximum trace-length: 6.2500E+00
#     getall: number of composite shots found in "field_smooth_2-Signature.sgy": 16
#     GetShotPointReceiverTracesInfo: number of composite shots found in "field_smooth_2-Observed.sgy": 16
#     scheduler_run: Starting new iteration block (2) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (3) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (4) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (5) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (6) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (7) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (8) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#   - scheduler_outputrunfile: dumping canonical runfile to field_smooth_2-Canonical-Runfile.key
# ---=== Checked input & dumped canonical runfile - finished on 2021/11/12, 21:21:42 ===---
#
# 3200+0 records in
# 6+1 records out
# 3200 bytes (3.2 kB, 3.1 KiB) copied, 0.00342639 s, 934 kB/s
#
# 24080 traces:
# tracl    3555 13370 (3555 - 13370)
# tracr    1 24080 (1 - 24080)
# fldr     17567 42821 (17567 - 42821)
# tracf    4104 4178 (4104 - 4176)
# ep       5 38 (5 - 38)
# cdpt     0 1 (0 - 1)
# trid     1
# offset   10 21208 (10473 - 19597)
# gelev    196 456 (417 - 410)
# selev    -12
# sdepth   12
# swdep    45 503 (395 - 393)
# gwdep    196 456 (417 - 410)
# scalel   1
# scalco   1
# sx       8051 24996 (8201 - 8128)
# sy       -2126 13847 (13742 - 13727)
# gx       8863 24030 (18674 - 21101)
# gy       -1040 13806 (13806 - -960)
# counit   1
# tstat    250
# delrt    0 5 (0 - 4)
# muts     338 6023 (3435 - 4990)
# mute     1338 7023 (4435 - 5990)
# ns       2500
# dt       2500
# gain     0 1 (1 - 0)
# igc      0 16 (16 - 0)
# year     2015
# day      331 340 (331 - 340)
# hour     0 23 (3 - 15)
# minute   0 59 (4 - 18)
# sec      0 59 (55 - 43)
# timbas   0 1000 (435 - 737)
# ntr      24080
# shortpad -20349 31289 (-20349 - 21520)
#
# Shot coordinate limits:
# 	North(23852,13847) South(10038,-2126) East(24996,656) West(8051,11996)
#
# Receiver coordinate limits:
# 	North(18674,13806) South(9821,-1040) East(24030,7042) West(8863,4208)
#
# Midpoint coordinate limits:
# 	North(21263,13826.5) South(9929.5,-1583) East(24513,3849) West(8457,8102)
#
# INFO:fullwavepy.project.generic.io.ProjInput.check_by_fullwave:
#
# Fullwave is checking the input...
# (exe = /home/kmc3817/light_PhD/fullwave3D/rev690/bin/fullwave3D.exe)
# INFO:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: Checked input & dumped canonical runfile
# WARNING:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: Note, accuracy criterion is not checked by Fullwave.
# WARNING:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: Make sure log_lvl<=20 in order to see the full log.
# INFO:fullwavepy.project.generic.io.ProjInput.check_by_fullwave: +++++++++++++++ Will only check input files and dump canonical runfile ++++++++++++++++
# ---=== Starting run (host: ese-kajetan) on 2021/11/12, 21:21:44 ===---
# executable: fullwave3D.exe, version: unknown, release date: 2021-08-31
# === scheduler_getprojargs: Project name (command-line argument): "field_smooth_3"
# === setup_probtype: Equation: "acoustic", Anisotropy: "none", Domain: "time", Kernel: "low"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "ibfs"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "multisurf"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "nosprdfctrs"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "seaLevel"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "maxGhostIter"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "vacuum"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "accuracy"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "minGhostFS"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "minFictFS"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "interpMode"
# +++ ReadParms: WARNING, unknown keyword in Runfile: "iprop"
#     read_runfile: number of iteration blocks in "field_smooth_3-Runfile.key": 8
#     read_runfile: total time given in "field_smooth_3-Runfile.key": 6.25000000 seconds
#     scheduler_readinput: Grid dimensions (Length x Width x Depth): 441x461x133 cells
#     read_modelprop: Got Vp model from "field_smooth_3-StartVp.sgy"
#     scheduler_readinput: Initial min/max Vp (m/s): 1517.41, 6515.07
#     scheduler_readinput: Initial min/max Qp: 0.00, 0.00
#     scheduler_readinput: Max. reliable pressure wave propagation frequency on this grid is about 6.07Hz
#     scheduler_run: Starting new iteration block (1) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     getall: Time-step: 2.5000E-03, maximum trace-length: 6.2500E+00
#     getall: number of composite shots found in "field_smooth_3-Signature.sgy": 16
#     GetShotPointReceiverTracesInfo: number of composite shots found in "field_smooth_3-Observed.sgy": 16
#     scheduler_run: Starting new iteration block (2) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (3) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (4) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (5) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (6) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (7) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#     scheduler_run: Starting new iteration block (8) with fnltag "2NRM"
#     scheduler_run: About to read trace data (NOTE: this can take time...)
#   - scheduler_outputrunfile: dumping canonical runfile to field_smooth_3-Canonical-Runfile.key
# ---=== Checked input & dumped canonical runfile - finished on 2021/11/12, 21:21:45 ===---
#
# 3200+0 records in
# 6+1 records out
# 3200 bytes (3.2 kB, 3.1 KiB) copied, 0.00252599 s, 1.3 MB/s
#
# 24080 traces:
# tracl    3555 13370 (3555 - 13370)
# tracr    1 24080 (1 - 24080)
# fldr     17567 42821 (17567 - 42821)
# tracf    4104 4178 (4104 - 4176)
# ep       5 38 (5 - 38)
# cdpt     0 1 (0 - 1)
# trid     1
# offset   10 21208 (10473 - 19597)
# gelev    196 456 (417 - 410)
# selev    -12
# sdepth   12
# swdep    45 503 (395 - 393)
# gwdep    196 456 (417 - 410)
# scalel   1
# scalco   1
# sx       8051 24996 (8201 - 8128)
# sy       -2126 13847 (13742 - 13727)
# gx       8863 24030 (18674 - 21101)
# gy       -1040 13806 (13806 - -960)
# counit   1
# tstat    250
# delrt    0 5 (0 - 4)
# muts     338 6023 (3435 - 4990)
# mute     1338 7023 (4435 - 5990)
# ns       2500
# dt       2500
# gain     0 1 (1 - 0)
# igc      0 16 (16 - 0)
# year     2015
# day      331 340 (331 - 340)
# hour     0 23 (3 - 15)
# minute   0 59 (4 - 18)
# sec      0 59 (55 - 43)
# timbas   0 1000 (435 - 737)
# ntr      24080
# shortpad -20349 31289 (-20349 - 21520)
#
# Shot coordinate limits:
# 	North(23852,13847) South(10038,-2126) East(24996,656) West(8051,11996)
#
# Receiver coordinate limits:
# 	North(18674,13806) South(9821,-1040) East(24030,7042) West(8863,4208)
#
# Midpoint coordinate limits:
# 	North(21263,13826.5) South(9929.5,-1583) East(24513,3849) West(8457,8102)
#
# CPU times: user 12 ms, sys: 36 ms, total: 48 ms
# Wall time: 8.46 s

# %% [markdown]
# # Run

# %%
# %%time 
for smooth, p in sorted(en.proj.items()):
#     p.reinit(path_eph) # only once, at start
    p.reinit('./')
#     p.i.pbs.no[0].prep(q='debug')
#     p.i.pbs.no[1].prep(hours=12, select=4, q='pqmrwarn') 
    # err: obs didn't sync for proj 1&3
#     p.i.pbs.no[2].prep(hours=1, select=4, q='pqmrwarn') # try again, shorter to test if OK
    # proj 3 run OK (2 iterations in 1 hour) but proj 1 failed (file-system issue, fixed)
    p.i.pbs.no[3].prep(hours=12, select=4, q='general') # general q. to save pq for others 
    # it took about 4 days (!) to wait in the queue...
    p.i.rsync('my_eph')
# Out:
# Content of  .//field_smooth_1//inp/field_smooth_1-Run3.pbs :
# #!/bin/bash
#
# ##
# # FULLWAVE3D WILL BE RUN FROM proj/out/
# # For more explanation, see help(fullwavepy.project.files.runfiles.PbsFile).
# #
# ##
#
# #PBS -N field_smooth_1
# #PBS -o ../out/field_smooth_1-JobOut3.log
# #PBS -e ../out/field_smooth_1-JobErr3.log
# #PBS -l walltime=12:00:00
# #PBS -l select=4:mpiprocs=8:ompthreads=4:ncpus=32:mem=62gb
# #PBS -l place=scatter:excl
#
# start=`date +%s`
#
#     # PATHS
#     code_path=~/PhD/fullwave3D/rev690/bin/fullwave3D.exe
#     echo 'code_path: '${code_path}
#
#     work_dir=$PBS_O_WORKDIR/../out/ # $PBS_O_WORKDIR IS THE ONE CONTAINING THIS SCRIPT
#
#     # CAVEAT
#     rm $work_dir/field_smooth_1-Runfile.key
#     rm $work_dir/field_smooth_1-Ghost.*
#
#
#     # HARD-LINK INPUT FILES TO OUTPUT DIR WHERE THE CODE WILL RUN
#     ln $PBS_O_WORKDIR/* $work_dir
#
#     # CHANGE DIRECTORY TO PROJECT OUTPUT
#     cd $work_dir
#
#
# # DISABLE PINNING OF THE PROCESSES (MAKE ALL NODE CORES AVAILABLE TO ALL PROCESSES)
# unset NCPUS
# export I_MPI_PIN=no # (DOES NOT WORK IF RUNNING ON A WHOLE NODE)
#
# # ARGUMENTS OF fullwave3D.exe
# CPNUM=-1
# NTHREAD=4 # EQUAL TO ompthreads
#
# # FULLWAVE'S ENVIRONMENT VARIABLES
# export SCHEDULER_ERRSTREAM=stderr
# export SCHEDULER_SHOWLEVEL=2
# export SCHEDULER_SHOWTIMESTAMP=yes
# export SCHEDULER_SLAVESHAVEDATA=yes
# export SCHEDULER_SLAVESHAVEMODEL=yes
# export SLAVES_DUMPCOMPARE=field_smooth_1-SLAVES_DUMPCOMPARE
# export SLAVES_ERRSTREAM=stderr
# export SLAVES_LOCALSTORE=$work_dir
# export SLAVES_LOCALSTORETRIGGER=40
# export SLAVES_SHOWLEVEL=2
# export SLAVES_SHOWTIMESTAMP=yes
#
# # LOAD MODULES
# module unload mpi/intel-2019
# module load mpi/intel-2018
# module load intel-suite
#
# #
# # INVERSION-RUN FLOW
# #
#
# # RUN FULLWAVE
# mpiexec ${code_path} field_smooth_1 ${CPNUM} ${NTHREAD} 1>> $work_dir/field_smooth_1-Out3.log 2>> $work_dir/field_smooth_1-Err3.log
#
# stat=$?
# echo "Exit status: "$stat
# for f in fw*iter*vtr bw*iter*vtr
# do
#   mv $f field_smooth_1-$f
# done
#
# end=`date +%s`
# runtime=$((end-start))
#
# echo 'Runtime of the PBS script: '$runtime' s'
#
# Content of  .//field_smooth_2//inp/field_smooth_2-Run3.pbs :
# #!/bin/bash
#
# ##
# # FULLWAVE3D WILL BE RUN FROM proj/out/
# # For more explanation, see help(fullwavepy.project.files.runfiles.PbsFile).
# #
# ##
#
# #PBS -N field_smooth_2
# #PBS -o ../out/field_smooth_2-JobOut3.log
# #PBS -e ../out/field_smooth_2-JobErr3.log
# #PBS -l walltime=12:00:00
# #PBS -l select=4:mpiprocs=8:ompthreads=4:ncpus=32:mem=62gb
# #PBS -l place=scatter:excl
#
# start=`date +%s`
#
#     # PATHS
#     code_path=~/PhD/fullwave3D/rev690/bin/fullwave3D.exe
#     echo 'code_path: '${code_path}
#
#     work_dir=$PBS_O_WORKDIR/../out/ # $PBS_O_WORKDIR IS THE ONE CONTAINING THIS SCRIPT
#
#     # CAVEAT
#     rm $work_dir/field_smooth_2-Runfile.key
#     rm $work_dir/field_smooth_2-Ghost.*
#
#
#     # HARD-LINK INPUT FILES TO OUTPUT DIR WHERE THE CODE WILL RUN
#     ln $PBS_O_WORKDIR/* $work_dir
#
#     # CHANGE DIRECTORY TO PROJECT OUTPUT
#     cd $work_dir
#
#
# # DISABLE PINNING OF THE PROCESSES (MAKE ALL NODE CORES AVAILABLE TO ALL PROCESSES)
# unset NCPUS
# export I_MPI_PIN=no # (DOES NOT WORK IF RUNNING ON A WHOLE NODE)
#
# # ARGUMENTS OF fullwave3D.exe
# CPNUM=-1
# NTHREAD=4 # EQUAL TO ompthreads
#
# # FULLWAVE'S ENVIRONMENT VARIABLES
# export SCHEDULER_ERRSTREAM=stderr
# export SCHEDULER_SHOWLEVEL=2
# export SCHEDULER_SHOWTIMESTAMP=yes
# export SCHEDULER_SLAVESHAVEDATA=yes
# export SCHEDULER_SLAVESHAVEMODEL=yes
# export SLAVES_DUMPCOMPARE=field_smooth_2-SLAVES_DUMPCOMPARE
# export SLAVES_ERRSTREAM=stderr
# export SLAVES_LOCALSTORE=$work_dir
# export SLAVES_LOCALSTORETRIGGER=40
# export SLAVES_SHOWLEVEL=2
# export SLAVES_SHOWTIMESTAMP=yes
#
# # LOAD MODULES
# module unload mpi/intel-2019
# module load mpi/intel-2018
# module load intel-suite
#
# #
# # INVERSION-RUN FLOW
# #
#
# # RUN FULLWAVE
# mpiexec ${code_path} field_smooth_2 ${CPNUM} ${NTHREAD} 1>> $work_dir/field_smooth_2-Out3.log 2>> $work_dir/field_smooth_2-Err3.log
#
# stat=$?
# echo "Exit status: "$stat
# for f in fw*iter*vtr bw*iter*vtr
# do
#   mv $f field_smooth_2-$f
# done
#
# end=`date +%s`
# runtime=$((end-start))
#
# echo 'Runtime of the PBS script: '$runtime' s'
#
# Content of  .//field_smooth_3//inp/field_smooth_3-Run3.pbs :
# #!/bin/bash
#
# ##
# # FULLWAVE3D WILL BE RUN FROM proj/out/
# # For more explanation, see help(fullwavepy.project.files.runfiles.PbsFile).
# #
# ##
#
# #PBS -N field_smooth_3
# #PBS -o ../out/field_smooth_3-JobOut3.log
# #PBS -e ../out/field_smooth_3-JobErr3.log
# #PBS -l walltime=12:00:00
# #PBS -l select=4:mpiprocs=8:ompthreads=4:ncpus=32:mem=62gb
# #PBS -l place=scatter:excl
#
# start=`date +%s`
#
#     # PATHS
#     code_path=~/PhD/fullwave3D/rev690/bin/fullwave3D.exe
#     echo 'code_path: '${code_path}
#
#     work_dir=$PBS_O_WORKDIR/../out/ # $PBS_O_WORKDIR IS THE ONE CONTAINING THIS SCRIPT
#
#     # CAVEAT
#     rm $work_dir/field_smooth_3-Runfile.key
#     rm $work_dir/field_smooth_3-Ghost.*
#
#
#     # HARD-LINK INPUT FILES TO OUTPUT DIR WHERE THE CODE WILL RUN
#     ln $PBS_O_WORKDIR/* $work_dir
#
#     # CHANGE DIRECTORY TO PROJECT OUTPUT
#     cd $work_dir
#
#
# # DISABLE PINNING OF THE PROCESSES (MAKE ALL NODE CORES AVAILABLE TO ALL PROCESSES)
# unset NCPUS
# export I_MPI_PIN=no # (DOES NOT WORK IF RUNNING ON A WHOLE NODE)
#
# # ARGUMENTS OF fullwave3D.exe
# CPNUM=-1
# NTHREAD=4 # EQUAL TO ompthreads
#
# # FULLWAVE'S ENVIRONMENT VARIABLES
# export SCHEDULER_ERRSTREAM=stderr
# export SCHEDULER_SHOWLEVEL=2
# export SCHEDULER_SHOWTIMESTAMP=yes
# export SCHEDULER_SLAVESHAVEDATA=yes
# export SCHEDULER_SLAVESHAVEMODEL=yes
# export SLAVES_DUMPCOMPARE=field_smooth_3-SLAVES_DUMPCOMPARE
# export SLAVES_ERRSTREAM=stderr
# export SLAVES_LOCALSTORE=$work_dir
# export SLAVES_LOCALSTORETRIGGER=40
# export SLAVES_SHOWLEVEL=2
# export SLAVES_SHOWTIMESTAMP=yes
#
# # LOAD MODULES
# module unload mpi/intel-2019
# module load mpi/intel-2018
# module load intel-suite
#
# #
# # INVERSION-RUN FLOW
# #
#
# # RUN FULLWAVE
# mpiexec ${code_path} field_smooth_3 ${CPNUM} ${NTHREAD} 1>> $work_dir/field_smooth_3-Out3.log 2>> $work_dir/field_smooth_3-Err3.log
#
# stat=$?
# echo "Exit status: "$stat
# for f in fw*iter*vtr bw*iter*vtr
# do
#   mv $f field_smooth_3-$f
# done
#
# end=`date +%s`
# runtime=$((end-start))
#
# echo 'Runtime of the PBS script: '$runtime' s'
#
# CPU times: user 316 ms, sys: 76 ms, total: 392 ms
# Wall time: 2.85 s

# %% [markdown]
# ## Logs

# %%
# %%time 
no = 2
for smooth, p in sorted(en.proj.items()):
    if smooth != 3:
        continue
    p.reinit(path_eph)
    p.o.o.no[no].cat()
# Out:
# Content of  /home/kmc3817/rds_home/my_ephemeral/PROJECTS/ch08_Kolumbo_volcano/field_smooth_3//out/field_smooth_3-Out2.log :
# # mpiexec: No RDMA network found -- using sockets+shared memory (I_MPI_DEVICE=ssm)
# # mpiexec: full path to program is /rds/general/user/kmc3817/home/PhD/fullwave3D/rev690/bin/fullwave3D.exe
# # mpiexec: program arguments are: field_smooth_3 -1 8
# # mpiexec: 20 ranks allocated via PBS select
# # mpiexec: 8 OpenMP threads / rank allocated by PBS select
# # mpiexec: Job has shared use of the allocated nodes. Disabling process-pinning
# # mpiexec: machinefile configured as:
# cx1-104-10-4.cx1.hpc.ic.ac.uk:5
# cx1-104-14-2.cx1.hpc.ic.ac.uk:5
# cx1-104-14-3.cx1.hpc.ic.ac.uk:5
# cx1-104-14-4.cx1.hpc.ic.ac.uk:5
# #
# # mpiexec: Checking all nodes are ONLINE:
# # mpiexec: All nodes appear ONLINE
# # mpiexec: launch started at Fri 12 Nov 19:47:52 GMT 2021
# # mpiexec: launching program...
# # /rds/general/user/kmc3817/home/PhD/fullwave3D/rev690/bin/fullwave3D.exe field_smooth_3 -1 8
# (cx1-104-10-4.cx1.hpc.ic.ac.uk:0,1,2,3,4)
# (cx1-104-14-2.cx1.hpc.ic.ac.uk:5,6,7,8,9)
# (cx1-104-14-3.cx1.hpc.ic.ac.uk:10,11,12,13,14)
# (cx1-104-14-4.cx1.hpc.ic.ac.uk:15,16,17,18,19)
# ---=== Starting run (host: cx1-104-10-4.cx1.hpc.ic.ac.uk) on 2021/11/12, 19:47:52 ===---
# executable: fullwave3D.exe, version: unknown, release date: 2021-11-12
# === [19:47:52] scheduler_getprojargs: Project name (command-line argument): "field_smooth_3"
# === [19:47:52] scheduler_getprojargs: Checkpoint number (command-line argument): -1
# === [19:47:52] setup_probtype: Equation: "acoustic", Anisotropy: "none", Domain: "time", Kernel: "low"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "ibfs"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "multisurf"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "nosprdfctrs"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "seaLevel"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "maxGhostIter"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "vacuum"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "accuracy"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "minGhostFS"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "minFictFS"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "interpMode"
# +++ [19:47:52] ReadParms: WARNING, unknown keyword in Runfile: "iprop"
#     [19:47:52] read_runfile: number of iteration blocks in "field_smooth_3-Runfile.key": 8
#     [19:47:52] read_runfile: total time given in "field_smooth_3-Runfile.key": 6.250000 seconds
#     [19:47:52] scheduler_readinput: Grid dimensions (Length x Width x Depth): 441x461x133 cells
#     [19:47:53] read_modelprop: Got Vp model from "field_smooth_3-StartVp.sgy"
#     [19:47:53] scheduler_readinput: Initial min/max Vp (m/s): 1517.41, 6515.07
#     [19:47:53] scheduler_readinput: Initial min/max Qp: 0.00, 0.00
#     [19:47:53] scheduler_readinput: Max. reliable pressure wave propagation frequency on this grid is about 6.07Hz
#     [19:47:53] scheduler_run: Starting new iteration block (1) with fnltag "2NRM"
#     [19:47:53] getall: Time-step: 2.5000E-03, maximum trace-length: 6.2500E+00
#     [19:47:53] getall: number of composite shots found in "field_smooth_3-Signature.sgy": 16
#     [19:47:53] GetShotPointReceiverTracesInfo: number of composite shots found in "field_smooth_3-Observed.sgy": 16
# ---=== Scheduler initialisation complete. Ready for slaves on 2021/11/12, 19:47:54 ===---
#     [19:47:55] (Slave16;CSRef4105;SrcID11) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:55] (Slave15;CSRef4112;SrcID3) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:56] (Slave16;CSRef4105;SrcID11) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:56] (Slave15;CSRef4112;SrcID3) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:56] (Slave11;CSRef4104;SrcID1) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:56] (Slave2;CSRef4138;SrcID14) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:56] (Slave1;CSRef4124;SrcID4) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:56] (Slave14;CSRef4178;SrcID10) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:56] (Slave13;CSRef4139;SrcID15) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:56] (Slave3;CSRef4157;SrcID7) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:56] (Slave12;CSRef4176;SrcID16) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:56] (Slave10;CSRef4125;SrcID5) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:56] (Slave4;CSRef4137;SrcID6) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:56] (Slave2;CSRef4138;SrcID14) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:56] (Slave11;CSRef4104;SrcID1) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:56] (Slave1;CSRef4124;SrcID4) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:56] (Slave14;CSRef4178;SrcID10) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:56] (Slave3;CSRef4157;SrcID7) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:56] (Slave13;CSRef4139;SrcID15) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:57] (Slave4;CSRef4137;SrcID6) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:57] (Slave12;CSRef4176;SrcID16) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:57] (Slave10;CSRef4125;SrcID5) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:57] (Slave8;CSRef4109;SrcID2) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:57] (Slave6;CSRef4158;SrcID8) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:57] (Slave5;CSRef4110;SrcID12) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:57] (Slave9;CSRef4123;SrcID13) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:57] (Slave7;CSRef4177;SrcID9) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [19:47:57] (Slave8;CSRef4109;SrcID2) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:57] (Slave6;CSRef4158;SrcID8) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:57] (Slave5;CSRef4110;SrcID12) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:57] (Slave9;CSRef4123;SrcID13) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:47:57] (Slave7;CSRef4177;SrcID9) boxesandfwstore: Local store trigger: 42949672960 bytes
#     [19:52:55] (Slave16;CSRef4105;SrcID11) calcResidsInfo: Traces fit 53.6% [tail 33.9%], fitting factor 5.830E-01 [tail 3.765E-01], norm ratio 1.000E+00
#     [19:53:14] (Slave15;CSRef4112;SrcID3) calcResidsInfo: Traces fit 27.3% [tail 59.7%], fitting factor 3.463E-01 [tail 5.591E-01], norm ratio 1.001E+00
#     [19:54:27] (Slave3;CSRef4157;SrcID7) calcResidsInfo: Traces fit 19.8% [tail -14.3%], fitting factor 2.785E-01 [tail 2.852E-01], norm ratio 1.000E+00
#     [19:54:28] (Slave4;CSRef4137;SrcID6) calcResidsInfo: Traces fit 31.6% [tail 9.2%], fitting factor 3.841E-01 [tail 1.944E-01], norm ratio 1.000E+00
#     [19:54:42] (Slave2;CSRef4138;SrcID14) calcResidsInfo: Traces fit 52.4% [tail 22.7%], fitting factor 5.721E-01 [tail 3.237E-01], norm ratio 1.001E+00
#     [19:54:44] (Slave1;CSRef4124;SrcID4) calcResidsInfo: Traces fit 25.4% [tail -82.8%], fitting factor 3.283E-01 [tail 1.665E-01], norm ratio 1.000E+00
#     [19:55:39] (Slave14;CSRef4178;SrcID10) calcResidsInfo: Traces fit 32.4% [tail 38.9%], fitting factor 3.920E-01 [tail 5.453E-01], norm ratio 1.001E+00
#     [19:55:42] (Slave11;CSRef4104;SrcID1) calcResidsInfo: Traces fit 37.8% [tail 55.2%], fitting factor 4.407E-01 [tail 6.349E-01], norm ratio 1.000E+00
#     [19:55:52] (Slave13;CSRef4139;SrcID15) calcResidsInfo: Traces fit 26.0% [tail 35.6%], fitting factor 3.345E-01 [tail 4.718E-01], norm ratio 1.001E+00
#     [19:55:59] (Slave12;CSRef4176;SrcID16) calcResidsInfo: Traces fit 48.3% [tail 24.6%], fitting factor 5.341E-01 [tail 2.342E-01], norm ratio 9.991E-01
#     [19:55:59] (Slave8;CSRef4109;SrcID2) calcResidsInfo: Traces fit 40.5% [tail -54.3%], fitting factor 4.647E-01 [tail 2.019E-01], norm ratio 1.001E+00
#     [19:55:59] (Slave10;CSRef4125;SrcID5) calcResidsInfo: Traces fit 38.0% [tail 52.7%], fitting factor 4.422E-01 [tail 5.752E-01], norm ratio 1.001E+00
#     [19:56:08] (Slave9;CSRef4123;SrcID13) calcResidsInfo: Traces fit 18.8% [tail 42.8%], fitting factor 2.696E-01 [tail 3.606E-01], norm ratio 1.001E+00
#     [19:56:15] (Slave6;CSRef4158;SrcID8) calcResidsInfo: Traces fit 53.5% [tail 49.8%], fitting factor 5.822E-01 [tail 6.715E-01], norm ratio 1.001E+00
#     [19:56:19] (Slave7;CSRef4177;SrcID9) calcResidsInfo: Traces fit 30.6% [tail 29.3%], fitting factor 3.759E-01 [tail 2.674E-01], norm ratio 1.001E+00
#     [19:56:32] (Slave5;CSRef4110;SrcID12) calcResidsInfo: Traces fit 46.5% [tail -15.0%], fitting factor 5.187E-01 [tail 2.963E-01], norm ratio 1.001E+00
#     [19:57:55] scheduler_slavefnlc: First fnlc for srcid 11 (slave 16): 1.724E+02 (got 1 of 16)
#     [19:58:28] scheduler_slavefnlc: First fnlc for srcid 3 (slave 15): 2.082E+02 (got 2 of 16)
#     [20:00:46] scheduler_slavefnlc: First fnlc for srcid 6 (slave 4): 2.026E+02 (got 3 of 16)
#     [20:01:08] scheduler_slavefnlc: First fnlc for srcid 7 (slave 3): 2.212E+02 (got 4 of 16)
#     [20:01:11] scheduler_slavefnlc: First fnlc for srcid 4 (slave 1): 2.142E+02 (got 5 of 16)
#     [20:01:29] scheduler_slavefnlc: First fnlc for srcid 14 (slave 2): 1.568E+02 (got 6 of 16)
#     [20:03:19] scheduler_slavefnlc: First fnlc for srcid 10 (slave 14): 2.267E+02 (got 7 of 16)
#     [20:03:27] scheduler_slavefnlc: First fnlc for srcid 1 (slave 11): 2.080E+02 (got 8 of 16)
#     [20:03:44] scheduler_slavefnlc: First fnlc for srcid 15 (slave 13): 2.128E+02 (got 9 of 16)
#     [20:03:47] scheduler_slavefnlc: First fnlc for srcid 5 (slave 10): 2.105E+02 (got 10 of 16)
#     [20:03:53] scheduler_slavefnlc: First fnlc for srcid 16 (slave 12): 1.947E+02 (got 11 of 16)
#     [20:04:10] scheduler_slavefnlc: First fnlc for srcid 2 (slave 8): 1.821E+02 (got 12 of 16)
#     [20:04:16] scheduler_slavefnlc: First fnlc for srcid 13 (slave 9): 2.249E+02 (got 13 of 16)
#     [20:04:17] scheduler_slavefnlc: First fnlc for srcid 8 (slave 6): 1.590E+02 (got 14 of 16)
#     [20:04:35] scheduler_slavefnlc: First fnlc for srcid 9 (slave 7): 2.087E+02 (got 15 of 16)
#     [20:04:42] scheduler_slavefnlc: First fnlc for srcid 12 (slave 5): 1.614E+02 (got 16 of 16)
#  -- [20:04:42] scheduler_slavefnlc: First global functional: 3.164E+03
#     [20:04:45] scheduler_globalupdate: ready to send update to 16 slaves (out of 16 sources)
#     [20:04:46] (Slave3;CSRef4157;SrcID7) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:46] (Slave4;CSRef4137;SrcID6) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:47] (Slave1;CSRef4124;SrcID4) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:48] (Slave2;CSRef4138;SrcID14) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:48] (Slave10;CSRef4125;SrcID5) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:51] (Slave15;CSRef4112;SrcID3) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:52] (Slave11;CSRef4104;SrcID1) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:53] (Slave14;CSRef4178;SrcID10) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:54] (Slave13;CSRef4139;SrcID15) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:55] (Slave16;CSRef4105;SrcID11) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:55] (Slave6;CSRef4158;SrcID8) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:56] (Slave8;CSRef4109;SrcID2) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:56] (Slave7;CSRef4177;SrcID9) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:57] (Slave5;CSRef4110;SrcID12) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:57] (Slave9;CSRef4123;SrcID13) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:04:57] (Slave12;CSRef4176;SrcID16) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:09:52] (Slave16;CSRef4105;SrcID11) calcResidsInfo: Traces fit 54.3% [tail 32.1%], fitting factor 5.886E-01 [tail 3.620E-01], norm ratio 1.000E+00
#     [20:09:52] scheduler_slavefnlc: Second fnlc for srcid 11 (slave 16): 1.707E+02 [-0.95%] (got 1 of 16, dots: 5.020E+00,3.522E+00)
#     [20:10:05] (Slave15;CSRef4112;SrcID3) calcResidsInfo: Traces fit 34.0% [tail 60.4%], fitting factor 4.063E-01 [tail 5.649E-01], norm ratio 1.001E+00
#     [20:10:06] scheduler_slavefnlc: Second fnlc for srcid 3 (slave 15): 1.990E+02 [-4.39%] (got 2 of 16, dots: 2.134E+01,6.235E+00)
#     [20:11:14] (Slave3;CSRef4157;SrcID7) calcResidsInfo: Traces fit 25.2% [tail -0.8%], fitting factor 3.271E-01 [tail 2.913E-01], norm ratio 1.000E+00
#     [20:11:15] scheduler_slavefnlc: Second fnlc for srcid 7 (slave 3): 2.158E+02 [-2.47%] (got 3 of 16, dots: 1.237E+01,2.926E+00)
#     [20:11:20] (Slave4;CSRef4137;SrcID6) calcResidsInfo: Traces fit 37.1% [tail 7.7%], fitting factor 4.342E-01 [tail 1.952E-01], norm ratio 1.000E+00
#     [20:11:20] scheduler_slavefnlc: Second fnlc for srcid 6 (slave 4): 1.947E+02 [-3.92%] (got 4 of 16, dots: 1.834E+01,5.003E+00)
#     [20:11:23] (Slave1;CSRef4124;SrcID4) calcResidsInfo: Traces fit 29.0% [tail -82.7%], fitting factor 3.611E-01 [tail 1.666E-01], norm ratio 1.000E+00
#     [20:11:23] scheduler_slavefnlc: Second fnlc for srcid 4 (slave 1): 2.096E+02 [-2.18%] (got 5 of 16, dots: 9.991E+00,1.367E+00)
#     [20:11:24] (Slave2;CSRef4138;SrcID14) calcResidsInfo: Traces fit 51.8% [tail 13.6%], fitting factor 5.667E-01 [tail 2.402E-01], norm ratio 1.001E+00
#     [20:11:24] scheduler_slavefnlc: Second fnlc for srcid 14 (slave 2): 1.582E+02 [0.92%] (got 6 of 16, dots: -1.920E+00,1.883E+00)
#     [20:12:26] (Slave11;CSRef4104;SrcID1) calcResidsInfo: Traces fit 40.9% [tail 52.9%], fitting factor 4.686E-01 [tail 6.368E-01], norm ratio 1.000E+00
#     [20:12:27] scheduler_slavefnlc: Second fnlc for srcid 1 (slave 11): 2.024E+02 [-2.71%] (got 7 of 16, dots: 1.272E+01,2.980E+00)
#     [20:12:28] (Slave13;CSRef4139;SrcID15) calcResidsInfo: Traces fit 21.2% [tail 47.1%], fitting factor 2.910E-01 [tail 5.782E-01], norm ratio 1.001E+00
#     [20:12:28] scheduler_slavefnlc: Second fnlc for srcid 15 (slave 13): 2.197E+02 [3.21%] (got 8 of 16, dots: -1.222E+01,2.751E+00)
#     [20:12:35] (Slave10;CSRef4125;SrcID5) calcResidsInfo: Traces fit 41.4% [tail 52.9%], fitting factor 4.731E-01 [tail 5.644E-01], norm ratio 1.001E+00
#     [20:12:35] scheduler_slavefnlc: Second fnlc for srcid 5 (slave 10): 2.041E+02 [-3.04%] (got 9 of 16, dots: 1.530E+01,5.139E+00)
#     [20:12:38] (Slave14;CSRef4178;SrcID10) calcResidsInfo: Traces fit 34.0% [tail 39.6%], fitting factor 4.062E-01 [tail 5.662E-01], norm ratio 1.001E+00
#     [20:12:39] scheduler_slavefnlc: Second fnlc for srcid 10 (slave 14): 2.238E+02 [-1.26%] (got 10 of 16, dots: 6.833E+00,2.290E+00)
#     [20:12:53] (Slave8;CSRef4109;SrcID2) calcResidsInfo: Traces fit 39.5% [tail -59.2%], fitting factor 4.562E-01 [tail 2.049E-01], norm ratio 1.001E+00
#     [20:12:53] scheduler_slavefnlc: Second fnlc for srcid 2 (slave 8): 1.837E+02 [0.87%] (got 11 of 16, dots: -2.267E+00,1.759E+00)
#     [20:12:57] (Slave12;CSRef4176;SrcID16) calcResidsInfo: Traces fit 50.2% [tail 30.8%], fitting factor 5.513E-01 [tail 2.771E-01], norm ratio 9.991E-01
#     [20:12:58] scheduler_slavefnlc: Second fnlc for srcid 16 (slave 12): 1.899E+02 [-2.44%] (got 12 of 16, dots: 1.091E+01,2.865E+00)
#     [20:13:05] (Slave6;CSRef4158;SrcID8) calcResidsInfo: Traces fit 51.1% [tail 40.0%], fitting factor 5.609E-01 [tail 5.513E-01], norm ratio 1.001E+00
#     [20:13:05] scheduler_slavefnlc: Second fnlc for srcid 8 (slave 6): 1.647E+02 [3.61%] (got 13 of 16, dots: -8.723E+00,5.393E+00)
#     [20:13:06] (Slave9;CSRef4123;SrcID13) calcResidsInfo: Traces fit 17.0% [tail 42.3%], fitting factor 2.536E-01 [tail 3.593E-01], norm ratio 1.001E+00
#     [20:13:06] scheduler_slavefnlc: Second fnlc for srcid 13 (slave 9): 2.266E+02 [0.80%] (got 14 of 16, dots: -3.092E+00,9.575E-01)
#     [20:13:15] (Slave5;CSRef4110;SrcID12) calcResidsInfo: Traces fit 44.6% [tail -19.7%], fitting factor 5.017E-01 [tail 2.908E-01], norm ratio 1.001E+00
#     [20:13:15] scheduler_slavefnlc: Second fnlc for srcid 12 (slave 5): 1.647E+02 [2.10%] (got 15 of 16, dots: -5.883E+00,1.722E+00)
#     [20:13:16] (Slave7;CSRef4177;SrcID9) calcResidsInfo: Traces fit 31.9% [tail 29.0%], fitting factor 3.873E-01 [tail 2.653E-01], norm ratio 1.001E+00
#     [20:13:16] scheduler_slavefnlc: Second fnlc for srcid 9 (slave 7): 2.065E+02 [-1.04%] (got 16 of 16, dots: 5.343E+00,2.040E+00)
# === [20:13:16] scheduler_globalstep: step-factor=2.166E+00, fnl1=3.164E+03, fnl2=3.134E+03 [-0.95%]
# === [20:13:23] scheduler_prepnextiter: done tomographic iteration 1 (of 20) for block "1"
#     [20:13:23] scheduler_checkpoint: writing run data to field_smooth_3-CP00001-Runfile.key
#     [20:13:23] scheduler_checkpoint: writing Vp to "field_smooth_3-CP00001-Vp.sgy" with dimensions 81x361x341
#     [20:13:24] (Slave13;CSRef4139;SrcID15) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave11;CSRef4104;SrcID1) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave6;CSRef4158;SrcID8) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave8;CSRef4109;SrcID2) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave1;CSRef4124;SrcID4) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave10;CSRef4125;SrcID5) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave7;CSRef4177;SrcID9) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave12;CSRef4176;SrcID16) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave2;CSRef4138;SrcID14) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave15;CSRef4112;SrcID3) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave14;CSRef4178;SrcID10) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave9;CSRef4123;SrcID13) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave5;CSRef4110;SrcID12) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave16;CSRef4105;SrcID11) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave4;CSRef4137;SrcID6) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:13:24] (Slave3;CSRef4157;SrcID7) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:18:23] (Slave16;CSRef4105;SrcID11) calcResidsInfo: Traces fit 54.2% [tail 29.8%], fitting factor 5.882E-01 [tail 3.443E-01], norm ratio 1.000E+00
#     [20:18:41] (Slave15;CSRef4112;SrcID3) calcResidsInfo: Traces fit 41.0% [tail 59.2%], fitting factor 4.700E-01 [tail 5.531E-01], norm ratio 1.001E+00
#     [20:19:53] (Slave3;CSRef4157;SrcID7) calcResidsInfo: Traces fit 31.1% [tail 14.5%], fitting factor 3.795E-01 [tail 3.453E-01], norm ratio 1.000E+00
#     [20:19:59] (Slave2;CSRef4138;SrcID14) calcResidsInfo: Traces fit 50.7% [tail 2.3%], fitting factor 5.565E-01 [tail 2.198E-01], norm ratio 1.001E+00
#     [20:20:08] (Slave4;CSRef4137;SrcID6) calcResidsInfo: Traces fit 43.0% [tail 6.0%], fitting factor 4.872E-01 [tail 1.957E-01], norm ratio 1.000E+00
#     [20:20:16] (Slave1;CSRef4124;SrcID4) calcResidsInfo: Traces fit 33.0% [tail -82.6%], fitting factor 3.972E-01 [tail 1.667E-01], norm ratio 1.000E+00
#     [20:21:03] (Slave13;CSRef4139;SrcID15) calcResidsInfo: Traces fit 15.4% [tail 58.3%], fitting factor 2.392E-01 [tail 6.755E-01], norm ratio 1.001E+00
#     [20:21:16] (Slave11;CSRef4104;SrcID1) calcResidsInfo: Traces fit 44.1% [tail 49.2%], fitting factor 4.967E-01 [tail 6.279E-01], norm ratio 1.000E+00
#     [20:21:17] (Slave14;CSRef4178;SrcID10) calcResidsInfo: Traces fit 35.4% [tail 40.4%], fitting factor 4.187E-01 [tail 5.894E-01], norm ratio 1.001E+00
#     [20:21:24] (Slave10;CSRef4125;SrcID5) calcResidsInfo: Traces fit 44.4% [tail 52.0%], fitting factor 5.001E-01 [tail 5.417E-01], norm ratio 1.001E+00
#     [20:21:25] (Slave8;CSRef4109;SrcID2) calcResidsInfo: Traces fit 38.0% [tail -63.4%], fitting factor 4.426E-01 [tail 2.089E-01], norm ratio 1.001E+00
#     [20:21:26] (Slave12;CSRef4176;SrcID16) calcResidsInfo: Traces fit 51.8% [tail 36.9%], fitting factor 5.658E-01 [tail 3.193E-01], norm ratio 9.991E-01
#     [20:21:30] (Slave9;CSRef4123;SrcID13) calcResidsInfo: Traces fit 15.0% [tail 41.0%], fitting factor 2.350E-01 [tail 3.520E-01], norm ratio 1.001E+00
#     [20:21:33] (Slave7;CSRef4177;SrcID9) calcResidsInfo: Traces fit 32.8% [tail 28.6%], fitting factor 3.953E-01 [tail 2.626E-01], norm ratio 1.001E+00
#     [20:21:49] (Slave5;CSRef4110;SrcID12) calcResidsInfo: Traces fit 42.1% [tail -24.3%], fitting factor 4.790E-01 [tail 2.836E-01], norm ratio 1.001E+00
#     [20:22:07] (Slave6;CSRef4158;SrcID8) calcResidsInfo: Traces fit 47.5% [tail 27.9%], fitting factor 5.280E-01 [tail 4.105E-01], norm ratio 1.001E+00
#     [20:23:22] scheduler_slavefnlc: First fnlc for srcid 11 (slave 16): 1.708E+02 [-0.90%] (got 1 of 16)
#     [20:23:55] scheduler_slavefnlc: First fnlc for srcid 3 (slave 15): 1.872E+02 [-10.07%] (got 2 of 16)
#     [20:26:19] scheduler_slavefnlc: First fnlc for srcid 14 (slave 2): 1.608E+02 [2.60%] (got 3 of 16)
#     [20:26:26] scheduler_slavefnlc: First fnlc for srcid 7 (slave 3): 2.083E+02 [-5.83%] (got 4 of 16)
#     [20:26:47] scheduler_slavefnlc: First fnlc for srcid 4 (slave 1): 2.040E+02 [-4.77%] (got 5 of 16)
#     [20:26:56] scheduler_slavefnlc: First fnlc for srcid 6 (slave 4): 1.844E+02 [-8.99%] (got 6 of 16)
#     [20:28:50] scheduler_slavefnlc: First fnlc for srcid 15 (slave 13): 2.269E+02 [6.61%] (got 7 of 16)
#     [20:28:51] scheduler_slavefnlc: First fnlc for srcid 13 (slave 9): 2.286E+02 [1.68%] (got 8 of 16)
#     [20:28:58] scheduler_slavefnlc: First fnlc for srcid 1 (slave 11): 1.963E+02 [-5.63%] (got 9 of 16)
#     [20:29:02] scheduler_slavefnlc: First fnlc for srcid 10 (slave 14): 2.212E+02 [-2.43%] (got 10 of 16)
#     [20:29:13] scheduler_slavefnlc: First fnlc for srcid 5 (slave 10): 1.978E+02 [-6.00%] (got 11 of 16)
#     [20:29:19] scheduler_slavefnlc: First fnlc for srcid 16 (slave 12): 1.858E+02 [-4.59%] (got 12 of 16)
#     [20:29:39] scheduler_slavefnlc: First fnlc for srcid 2 (slave 8): 1.862E+02 [2.24%] (got 13 of 16)
#     [20:29:45] scheduler_slavefnlc: First fnlc for srcid 9 (slave 7): 2.049E+02 [-1.79%] (got 14 of 16)
#     [20:30:14] scheduler_slavefnlc: First fnlc for srcid 12 (slave 5): 1.691E+02 [4.77%] (got 15 of 16)
#     [20:30:16] scheduler_slavefnlc: First fnlc for srcid 8 (slave 6): 1.730E+02 [8.85%] (got 16 of 16)
#  -- [20:30:16] scheduler_slavefnlc: First global functional: 3.105E+03 [change: -1.85%]
#     [20:30:25] scheduler_globalupdate: ready to send update to 16 slaves (out of 16 sources)
#     [20:30:25] (Slave2;CSRef4138;SrcID14) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:25] (Slave4;CSRef4137;SrcID6) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:25] (Slave3;CSRef4157;SrcID7) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:25] (Slave1;CSRef4124;SrcID4) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:30] (Slave14;CSRef4178;SrcID10) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:30] (Slave11;CSRef4104;SrcID1) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:35] (Slave16;CSRef4105;SrcID11) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:35] (Slave5;CSRef4110;SrcID12) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:35] (Slave6;CSRef4158;SrcID8) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:35] (Slave10;CSRef4125;SrcID5) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:36] (Slave9;CSRef4123;SrcID13) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:36] (Slave8;CSRef4109;SrcID2) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:36] (Slave13;CSRef4139;SrcID15) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:36] (Slave7;CSRef4177;SrcID9) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:36] (Slave12;CSRef4176;SrcID16) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:30:36] (Slave15;CSRef4112;SrcID3) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:35:32] (Slave16;CSRef4105;SrcID11) calcResidsInfo: Traces fit 54.0% [tail 28.6%], fitting factor 5.861E-01 [tail 3.359E-01], norm ratio 1.000E+00
#     [20:35:32] scheduler_slavefnlc: Second fnlc for srcid 11 (slave 16): 1.714E+02 [0.36%] (got 1 of 16, dots: -5.445E-01,1.342E+00)
#     [20:35:51] (Slave15;CSRef4112;SrcID3) calcResidsInfo: Traces fit 44.9% [tail 57.6%], fitting factor 5.048E-01 [tail 5.382E-01], norm ratio 1.001E+00
#     [20:35:51] scheduler_slavefnlc: Second fnlc for srcid 3 (slave 15): 1.798E+02 [-3.97%] (got 2 of 16, dots: 1.647E+01,3.308E+00)
#     [20:36:43] (Slave3;CSRef4157;SrcID7) calcResidsInfo: Traces fit 34.3% [tail 23.2%], fitting factor 4.090E-01 [tail 4.708E-01], norm ratio 1.000E+00
#     [20:36:43] scheduler_slavefnlc: Second fnlc for srcid 7 (slave 3): 2.033E+02 [-2.40%] (got 3 of 16, dots: 1.110E+01,2.238E+00)
#     [20:36:56] (Slave4;CSRef4137;SrcID6) calcResidsInfo: Traces fit 46.4% [tail 5.1%], fitting factor 5.179E-01 [tail 1.958E-01], norm ratio 1.000E+00
#     [20:36:57] scheduler_slavefnlc: Second fnlc for srcid 6 (slave 4): 1.776E+02 [-3.72%] (got 4 of 16, dots: 1.496E+01,2.576E+00)
#     [20:36:59] (Slave2;CSRef4138;SrcID14) calcResidsInfo: Traces fit 49.9% [tail -4.1%], fitting factor 5.495E-01 [tail 2.213E-01], norm ratio 1.001E+00
#     [20:37:00] scheduler_slavefnlc: Second fnlc for srcid 14 (slave 2): 1.626E+02 [1.11%] (got 5 of 16, dots: -3.162E+00,8.121E-01)
#     [20:37:15] (Slave1;CSRef4124;SrcID4) calcResidsInfo: Traces fit 35.4% [tail -82.5%], fitting factor 4.184E-01 [tail 1.667E-01], norm ratio 1.000E+00
#     [20:37:15] scheduler_slavefnlc: Second fnlc for srcid 4 (slave 1): 2.006E+02 [-1.70%] (got 6 of 16, dots: 7.601E+00,1.393E+00)
#     [20:38:00] (Slave14;CSRef4178;SrcID10) calcResidsInfo: Traces fit 36.0% [tail 40.9%], fitting factor 4.248E-01 [tail 6.018E-01], norm ratio 1.001E+00
#     [20:38:01] scheduler_slavefnlc: Second fnlc for srcid 10 (slave 14): 2.198E+02 [-0.62%] (got 7 of 16, dots: 3.328E+00,1.155E+00)
#     [20:38:15] (Slave11;CSRef4104;SrcID1) calcResidsInfo: Traces fit 45.7% [tail 46.3%], fitting factor 5.116E-01 [tail 6.128E-01], norm ratio 1.000E+00
#     [20:38:16] scheduler_slavefnlc: Second fnlc for srcid 1 (slave 11): 1.928E+02 [-1.75%] (got 8 of 16, dots: 7.547E+00,1.397E+00)
#     [20:38:20] (Slave13;CSRef4139;SrcID15) calcResidsInfo: Traces fit 12.3% [tail 63.8%], fitting factor 2.109E-01 [tail 7.200E-01], norm ratio 1.001E+00
#     [20:38:20] scheduler_slavefnlc: Second fnlc for srcid 15 (slave 13): 2.305E+02 [1.59%] (got 9 of 16, dots: -6.554E+00,1.276E+00)
#     [20:38:21] (Slave10;CSRef4125;SrcID5) calcResidsInfo: Traces fit 45.8% [tail 50.9%], fitting factor 5.123E-01 [tail 5.253E-01], norm ratio 1.001E+00
#     [20:38:22] scheduler_slavefnlc: Second fnlc for srcid 5 (slave 10): 1.946E+02 [-1.62%] (got 10 of 16, dots: 7.655E+00,2.564E+00)
#     [20:38:35] (Slave12;CSRef4176;SrcID16) calcResidsInfo: Traces fit 52.4% [tail 39.4%], fitting factor 5.712E-01 [tail 3.358E-01], norm ratio 9.991E-01
#     [20:38:36] scheduler_slavefnlc: Second fnlc for srcid 16 (slave 12): 1.841E+02 [-0.88%] (got 11 of 16, dots: 3.771E+00,1.041E+00)
#     [20:38:42] (Slave9;CSRef4123;SrcID13) calcResidsInfo: Traces fit 13.9% [tail 40.0%], fitting factor 2.257E-01 [tail 3.452E-01], norm ratio 1.001E+00
#     [20:38:42] scheduler_slavefnlc: Second fnlc for srcid 13 (slave 9): 2.295E+02 [0.39%] (got 12 of 16, dots: -1.600E+00,3.395E-01)
#     [20:38:45] (Slave7;CSRef4177;SrcID9) calcResidsInfo: Traces fit 33.2% [tail 28.4%], fitting factor 3.986E-01 [tail 2.614E-01], norm ratio 1.001E+00
#     [20:38:45] scheduler_slavefnlc: Second fnlc for srcid 9 (slave 7): 2.043E+02 [-0.32%] (got 13 of 16, dots: 1.765E+00,8.734E-01)
#     [20:38:46] (Slave8;CSRef4109;SrcID2) calcResidsInfo: Traces fit 37.0% [tail -65.0%], fitting factor 4.338E-01 [tail 2.108E-01], norm ratio 1.001E+00
#     [20:38:47] scheduler_slavefnlc: Second fnlc for srcid 2 (slave 8): 1.877E+02 [0.82%] (got 14 of 16, dots: -2.677E+00,7.614E-01)
#     [20:38:48] (Slave6;CSRef4158;SrcID8) calcResidsInfo: Traces fit 45.2% [tail 22.0%], fitting factor 5.075E-01 [tail 3.437E-01], norm ratio 1.001E+00
#     [20:38:49] scheduler_slavefnlc: Second fnlc for srcid 8 (slave 6): 1.777E+02 [2.70%] (got 15 of 16, dots: -8.187E+00,2.206E+00)
#     [20:38:56] (Slave5;CSRef4110;SrcID12) calcResidsInfo: Traces fit 40.7% [tail -25.9%], fitting factor 4.665E-01 [tail 2.805E-01], norm ratio 1.001E+00
#     [20:38:56] scheduler_slavefnlc: Second fnlc for srcid 12 (slave 5): 1.713E+02 [1.34%] (got 16 of 16, dots: -4.193E+00,6.546E-01)
# === [20:38:56] scheduler_globalstep: step-factor=2.426E+00, fnl1=3.105E+03 [-1.85%], fnl2=3.088E+03 [-0.57%]
# === [20:39:04] scheduler_prepnextiter: done tomographic iteration 2 (of 20) for block "1"
#     [20:39:04] scheduler_checkpoint: writing run data to field_smooth_3-CP00002-Runfile.key
#     [20:39:04] scheduler_checkpoint: writing Vp to "field_smooth_3-CP00002-Vp.sgy" with dimensions 81x361x341
#     [20:39:05] (Slave2;CSRef4138;SrcID14) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave1;CSRef4124;SrcID4) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave15;CSRef4112;SrcID3) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave11;CSRef4104;SrcID1) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave16;CSRef4105;SrcID11) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave6;CSRef4158;SrcID8) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave9;CSRef4123;SrcID13) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave7;CSRef4177;SrcID9) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave13;CSRef4139;SrcID15) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave4;CSRef4137;SrcID6) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave3;CSRef4157;SrcID7) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave12;CSRef4176;SrcID16) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave14;CSRef4178;SrcID10) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:05] (Slave8;CSRef4109;SrcID2) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:06] (Slave10;CSRef4125;SrcID5) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:39:06] (Slave5;CSRef4110;SrcID12) slave_timesolve: starting 2500 time-steps with 8 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [20:44:05] (Slave16;CSRef4105;SrcID11) calcResidsInfo: Traces fit 53.3% [tail 27.0%], fitting factor 5.794E-01 [tail 3.239E-01], norm ratio 1.000E+00
#     [20:44:26] (Slave15;CSRef4112;SrcID3) calcResidsInfo: Traces fit 49.7% [tail 54.3%], fitting factor 5.483E-01 [tail 5.075E-01], norm ratio 1.001E+00
#     [20:45:25] (Slave3;CSRef4157;SrcID7) calcResidsInfo: Traces fit 38.6% [tail 35.1%], fitting factor 4.470E-01 [tail 6.518E-01], norm ratio 1.000E+00
#     [20:45:35] (Slave2;CSRef4138;SrcID14) calcResidsInfo: Traces fit 48.6% [tail -13.6%], fitting factor 5.374E-01 [tail 2.231E-01], norm ratio 1.001E+00
#     [20:45:58] (Slave4;CSRef4137;SrcID6) calcResidsInfo: Traces fit 50.7% [tail 3.9%], fitting factor 5.566E-01 [tail 1.955E-01], norm ratio 1.000E+00
#     [20:46:05] (Slave1;CSRef4124;SrcID4) calcResidsInfo: Traces fit 38.5% [tail -82.4%], fitting factor 4.468E-01 [tail 1.668E-01], norm ratio 1.000E+00
#     [20:46:45] (Slave14;CSRef4178;SrcID10) calcResidsInfo: Traces fit 36.7% [tail 41.6%], fitting factor 4.310E-01 [tail 6.178E-01], norm ratio 1.001E+00
#     [20:46:51] (Slave13;CSRef4139;SrcID15) calcResidsInfo: Traces fit 7.9% [tail 70.1%], fitting factor 2.002E-01 [tail 7.677E-01], norm ratio 1.001E+00
#     [20:46:59] (Slave11;CSRef4104;SrcID1) calcResidsInfo: Traces fit 47.8% [tail 41.4%], fitting factor 5.300E-01 [tail 5.796E-01], norm ratio 1.000E+00
#     [20:47:03] (Slave12;CSRef4176;SrcID16) calcResidsInfo: Traces fit 53.0% [tail 42.3%], fitting factor 5.761E-01 [tail 3.552E-01], norm ratio 9.991E-01
#     [20:47:10] (Slave10;CSRef4125;SrcID5) calcResidsInfo: Traces fit 47.0% [tail 48.9%], fitting factor 5.231E-01 [tail 4.986E-01], norm ratio 1.001E+00
#     [20:47:13] (Slave9;CSRef4123;SrcID13) calcResidsInfo: Traces fit 12.5% [tail 38.1%], fitting factor 2.130E-01 [tail 3.320E-01], norm ratio 1.001E+00
#     [20:47:13] (Slave7;CSRef4177;SrcID9) calcResidsInfo: Traces fit 33.3% [tail 28.1%], fitting factor 4.002E-01 [tail 2.598E-01], norm ratio 1.001E+00
#     [20:47:14] (Slave8;CSRef4109;SrcID2) calcResidsInfo: Traces fit 35.4% [tail -66.5%], fitting factor 4.194E-01 [tail 2.136E-01], norm ratio 1.001E+00
#     [20:47:27] (Slave6;CSRef4158;SrcID8) calcResidsInfo: Traces fit 41.6% [tail 13.4%], fitting factor 4.747E-01 [tail 2.503E-01], norm ratio 1.001E+00
#     [20:47:39] (Slave5;CSRef4110;SrcID12) calcResidsInfo: Traces fit 38.5% [tail -27.9%], fitting factor 4.473E-01 [tail 2.761E-01], norm ratio 1.001E+00
#
# CPU times: user 136 ms, sys: 56 ms, total: 192 ms
# Wall time: 472 ms

# %% [markdown]
# # Out

# %% [markdown]
# ## Files list

# %%
# %%time 
# for smooth, p in sorted(en.proj.items()):
#     p.reinit(path_eph)
#     p.o.ls()
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 5.25 µs

# %% [markdown]
# ## Objective function

# %%
# %%time 
for smooth, p in sorted(en.proj.items()):
    if smooth != 2:
        continue
    p.reinit(path_eph)
    fig = figure(14,8)
    p.o.fit.plot(run_ids=[1,3], fig=fig, legend_size=16)
    plt.grid()
    plt.ylim(20,100)
# Out:
# CPU times: user 192 ms, sys: 36 ms, total: 228 ms
# Wall time: 3.54 s

# %% [markdown]
# ## Data fit

# %% [markdown]
# ### Phase plots

# %% [markdown]
# ### Waveform plots

# %% [markdown]
# ## Recovered model

# %%
p.o.vp.it[25]

# %%
# %%time 
for smooth, p in sorted(en.proj.items()):
    if smooth != 2:
        continue
    p.reinit(path_eph)
    p.o.vp.it[25].plot(coord=235,  overwrite_mmp=0)
# Out:
# CPU times: user 252 ms, sys: 32 ms, total: 284 ms
# Wall time: 772 ms

# %% [markdown]
# # ...
